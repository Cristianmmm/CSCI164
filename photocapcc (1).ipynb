# %%
import warnings
warnings.filterwarnings(action = 'ignore')

# %%
from transformers import pipeline
from transformers.utils import logging
logging.set_verbosity(40)

# %%
from IPython.display import Image

# %%
#Image 1
#https://drive.google.com/file/d/1Y71m4yECR-ullH8mUuJntX-QVnzQULA6/view?usp=drive_link
# !gdown 1Y71m4yECR-ullH8mUuJntX-QVnzQULA6
file_name1 = "Image1.jpg"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Y71m4yECR-ullH8mUuJntX-QVnzQULA6
# To: /content/Image1.jpg
# 100% 14.1k/14.1k [00:00<00:00, 41.5MB/s]

# %%
#Image 2
#https://drive.google.com/file/d/1Qfq49vdR-DFat0URyMgh83H5BrROMPXI/view?usp=drive_link
# !gdown 1Qfq49vdR-DFat0URyMgh83H5BrROMPXI
file_name2 = "Image2.jpg"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Qfq49vdR-DFat0URyMgh83H5BrROMPXI
# To: /content/Image2.jpg
# 100% 113k/113k [00:00<00:00, 43.5MB/s]

# %%
#Image 3
#https://drive.google.com/file/d/1zWrT424zHfF9a7JZv-5iE8WXPBybSiHw/view?usp=drive_link
# !gdown 1zWrT424zHfF9a7JZv-5iE8WXPBybSiHw
file_name3 = "Image3.jpg"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1zWrT424zHfF9a7JZv-5iE8WXPBybSiHw
# To: /content/Image3.jpg
# 100% 12.0k/12.0k [00:00<00:00, 28.5MB/s]

# %%
#Task: Image captioning
captioner = pipeline(task = "image-to-text", model = "nlpconnect/vit-gpt2-image-captioning")
# Out:
# config.json:   0%|          | 0.00/4.61k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/982M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/241 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/120 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/228 [00:00<?, ?B/s]

# %%
file_name = file_name1

# %%
captioner2 = pipeline("image-to-text", model = "Salesforce/blip-image-captioning-base")
# Out:
# config.json:   0%|          | 0.00/4.56k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/506 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/287 [00:00<?, ?B/s]

# %%
captioner3 = pipeline("image-to-text", model = "microsoft/git-large-textcaps")
# Out:
# config.json:   0%|          | 0.00/2.82k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.58G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/141 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/453 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/503 [00:00<?, ?B/s]

# %%
display(Image(filename = file_name1))
print(captioner(file_name))
# Out:
# [{'generated_text': 'a man is eating a doughnut in a bathroom '}]

# %%
print(captioner2(file_name))
# Out:
# [{'generated_text': 'a man in a yellow shirt is holding a cell'}]

# %%
print(captioner3(file_name))
# Out:
# [{'generated_text': 'a man with a nose that is making a heart shape with his hands.'}]

# %%
display(Image(filename = file_name2))
print(captioner(file_name2))
# Out:
# [{'generated_text': 'a painting of a person holding a bunch of colorful umbrellas '}]

# %%
print(captioner2(file_name2))
# Out:
# [{'generated_text': 'a painting of a woman with balloons'}]

# %%
print(captioner3(file_name2))
# Out:
# [{'generated_text': 'a painting of a woman and a man with a ball on their head'}]

# %%
display(Image(filename = file_name3))
print(captioner(file_name3))
# Out:
# [{'generated_text': 'a pair of blue and white street signs '}]

# %%
print(captioner2(file_name3))
# Out:
# [{'generated_text': 'the mh - 1 in - ear headphones'}]

# %%
print(captioner3(file_name3))
# Out:
# [{'generated_text': 'a pair of blue and black headphones with the m & r on the back.'}]
